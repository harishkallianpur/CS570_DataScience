# %% [markdown]
# <p style="color:blue">Import the necessary toolkits and libraries namely: Natural Language Toolkit (nltk), Regular Expressions (re), Sci Toolkit (sklearn)</p>

# %%
import nltk
import re
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.datasets import fetch_20newsgroups

# %% [markdown]
# <p style="color:blue">Fetch data from newsgroup 'sci.space' </p>("I am interested in space & astronomy")

# %%
categories = ['sci.space']
dataset = fetch_20newsgroups(subset='all',shuffle=True, random_state=42, categories=categories)
corpus = dataset.data

# %% [markdown]
# <p style="color:blue">Let us glance the raw data retrieved from the newsgroup</p>

# %%
corpus[0]
# Out:
# u'From: aws@iti.org (Allen W. Sherzer)\nSubject: Re: Orbital RepairStation\nOrganization: Evil Geniuses for a Better Tomorrow\nLines: 20\n\nIn article <C5HCBo.Joy@zoo.toronto.edu> henry@zoo.toronto.edu (Henry Spencer) writes:\n\n>The biggest problem with this is that all orbits are not alike.  It can\n>actually be more expensive to reach a satellite from another orbit than\n>from the ground.  \n\nBut with cheaper fuel from space based sources it will be cheaper to \nreach more orbits than from the ground.\n\nAlso remember, that the presence of a repair/supply facility adds value\nto the space around it. If you can put your satellite in an orbit where it\ncan be reached by a ready source of supply you can make it cheaper and gain\nbenefit from economies of scale.\n\n  Allen\n-- \n+---------------------------------------------------------------------------+\n| Lady Astor:   "Sir, if you were my husband I would poison your coffee!"   |\n| W. Churchill: "Madam, if you were my wife, I would drink it."             |\n+----------------------58 DAYS TO FIRST FLIGHT OF DCX-----------------------+\n'

# %%
len(corpus)
# Out:
# 987

# %% [markdown]
# <h4>Observation</h4>
# <p style="color:brown">
# There are 987 posts. Each typical post has the format: <br>
#     "From: {EmailId} \nSubject: {Text} \nOrganization: {Text} \nLines: {# of lines} {Content}" <br>
# There are lots of \n, Special characters, numbers and other text that needs to be cleaned. We will be interested in the {Content} portion to extract meaningful information
# </p>

# %% [markdown]
# <p style="color:blue">
# Convert content into lower case
# </p>

# %%
corpus = [x.lower() for x in corpus]

# %% [markdown]
# <p style="color:blue">
# Clean 'corpus' as follows:
# <ul>
# <li>Extract substring that follows 'lines'</li>
# <li>Replace \n with a space</li>
# <li>Replace " with a space</li>
# <li>Replace special characters with a space</li>
# <li>Replace numbers with a space</li>
# <li>Replace multiple spaces with a single space</li>
# </ul>
# </p>

# %%
cleancorpus = []
for x in corpus:
    cleanline = x[x.find("lines: ")+7:]
    cleanline = cleanline.replace("\n"," ")
    cleanline = cleanline.replace("\\"," ")
    cleanline = cleanline.replace("\""," ")
    cleanline = re.sub( '[(,!)<+=_*&>#%|{:;`~?/}-]', ' ', cleanline )
    cleanline = re.sub( '[0-9]', ' ', cleanline )    
    cleanline = re.sub( '\s+', ' ', cleanline )    
    cleancorpus.append(cleanline)

# %% [markdown]
# <p style="color:blue">
# Let us check the progress on the cleanup. We will be using 'cleancorpus' for our further analysis
# </p>

# %%
cleancorpus[0]
# Out:
# u' in article c hcbo.joy@zoo.toronto.edu henry@zoo.toronto.edu henry spencer writes the biggest problem with this is that all orbits are not alike. it can actually be more expensive to reach a satellite from another orbit than from the ground. but with cheaper fuel from space based sources it will be cheaper to reach more orbits than from the ground. also remember that the presence of a repair supply facility adds value to the space around it. if you can put your satellite in an orbit where it can be reached by a ready source of supply you can make it cheaper and gain benefit from economies of scale. allen lady astor sir if you were my husband i would poison your coffee w. churchill madam if you were my wife i would drink it. days to first flight of dcx '

# %% [markdown]
# <h4>Observation</h4>
# <p style="color:brown">
# Email addresses need to be removed
# </p>

# %% [markdown]
# <p style="color:blue">
# We now proceed with extracting a list of emails from 'cleancorpus'. Credit for this regex and corresponding function to extract email goes to
# Dennis Ideler at https://gist.github.com/dideler/5219706
# </p>

# %%
regex = re.compile(("([a-z0-9!#$%&'*+\/=?^_`{|}~-]+(?:\.[a-z0-9!#$%&'*+\/=?^_`"
                    "{|}~-]+)*(@|\sat\s)(?:[a-z0-9](?:[a-z0-9-]*[a-z0-9])?(\.|"
                    "\sdot\s))+[a-z0-9](?:[a-z0-9-]*[a-z0-9])?)"))

# %%
def get_emails(s):
    """Returns an iterator of matched emails found in string s."""
    # Removing lines that start with '//' because the regular expression
    # mistakenly matches patterns like 'http://foo@bar.com' as '//foo@bar.com'.
    return (email[0] for email in re.findall(regex, s) if not email[0].startswith('//'))

# %% [markdown]
# <p style="color:blue">
# Extract the emails from 'cleancorpus' into 'emails'
# </p>

# %%
emails = []

for x in cleancorpus:
    for email in get_emails(x):
       emails.append(email)

# %%
emails
# Out:
# [u'hcbo.joy@zoo.toronto.edu',
#  u'henry@zoo.toronto.edu',
#  u'aws@iti.org',
#  u'cspara.decnet@fedex.msfc.nasa.gov',
#  u'lek@aip.org',
#  u'dennisn@ecs.comm.mot.com',
#  u'maverick@wpi.wpi.edu',
#  u's@andrew.cmu.edu',
#  u'henry@zoo.toronto.edu',
#  u'prb@access.digex.com',
#  u'dragon@access.digex.com',
#  u'aws@iti.org',
#  u'nsmca@aurora.alaska.edu',
#  u'rinnett@mojo.eng.umd.edu',
#  u'sysmgr@king.eng.umd.edu',
#  u'higgins@fnalf.fnal.gov',
#  u'sysmgr@cadlab.eng.umd.edu',
#  u'clarke@acme.ucf.edu',
#  u'henry@zoo.toronto.edu',
#  u'jfc@athena.mit.edu',
#  u'henry@zoo.toronto.edu',
#  u'w@theporch.raider.net',
#  u'gene@theporch.raider.net',
#  u'gene@theporch.raider.net',
#  u'sysmgr@king.eng.umd.edu',
#  u'ikc@zoo.toronto.edu',
#  u'henry@zoo.toronto.edu',
#  u'sysmgr@cadlab.eng.umd.edu',
#  u'dkelo@pepvax.pepperdine.edu',
#  u'prb@access.digex.net',
#  u'prb@access.digex.net',
#  u'snydefj@eng.auburn.edu',
#  u'henry@zoo.toronto.edu',
#  u'teezee@netcom.com',
#  u'tffreeba@indyvax.iupui.edu',
#  u'gnb@bby.com.au',
#  u'steinly@topaz.ucsc.edu',
#  u'steinly@topaz.ucsc.edu',
#  u'steinly@topaz.ucsc.edu',
#  u'ph@babbage.sissa.it',
#  u'wawers@sunny.lif.de',
#  u'steinly@topaz.ucsc.edu',
#  u'steinly@topaz.ucsc.edu',
#  u'steinly@topaz.ucsc.edu',
#  u'rhoc.fty@news.cso.uiuc.edu',
#  u'innjkv@gap.caltech.edu',
#  u'jafoust@cco.caltech.edu',
#  u'innjkv@gap.caltech.edu',
#  u'jafoust@cco.caltech.edu',
#  u'jdnicoll@prism.ccs.uwo.ca',
#  u'steinly@lick.ucsc.edu',
#  u'nsmca@aurora.alaska.edu',
#  u'baalke@kelvin.jpl.nasa.gov',
#  u'baalke@kelvin.jpl.nasa.gov',
#  u'jennise@dgi.com',
#  u'ff@rave.larc.nasa.gov',
#  u'c.o.egalon@larc.nasa.gov',
#  u'henry@zoo.toronto.edu',
#  u'flb@flb.optiplan.fi',
#  u'dennisn@ecs.comm.mot.com',
#  u'baalke@kelvin.jpl.nasa.gov',
#  u'jmcocker@eos.ncsu.edu',
#  u'pc@news.cso.uiuc.edu',
#  u'rls@uihepa.hep.uiuc.edu',
#  u'henry@zoo.toronto.edu',
#  u'dmcaloon@tuba.calpoly.edu',
#  u'henry@zoo.toronto.edu',
#  u'palmer@alumni.caltech.edu',
#  u'palmer@tgrs.gsfc.nasa.gov',
#  u'khayash@hsc.usc.edu',
#  u'bruce.scott@launchpad.unc.edu',
#  u'gbt@zia.cray.com',
#  u'schemers@slapshot.stanford.edu',
#  u'rrhlo$ajb@access.digex.net',
#  u'prb@access.digex.net',
#  u'hathaway@stsci.edu',
#  u'i@access.digex.net',
#  u'prb@access.digex.net',
#  u'nhg@rpi.edu',
#  u'strider@clotho.acm.rpi.edu',
#  u'henry@zoo.toronto.edu',
#  u'harrisd@ll.mit.edu',
#  u'wingert@vnet.ibm.com',
#  u'wingert@vnet.ibm.com',
#  u'perky@acs.bu.edu',
#  u'perky@acs.bu.edu',
#  u'stgprao@st.unocal.com',
#  u'turner@bigbang.astro.indiana.edu',
#  u'baalke@kelvin.jpl.nasa.gov',
#  u'jgreen@trumpet.calpoly.edu',
#  u'pyron@skndiv.dseg.ti.com',
#  u'fred.mccall@dseg.ti.com',
#  u'jgreen@oboe.calpoly.edu',
#  u'eugene@orville.nas.nasa.gov',
#  u'gene@theporch.raider.net',
#  u'jpw@cbis.ece.drexel.edu',
#  u'pearson@titan.tsd.arlut.utexas.edu',
#  u'baube@optiplan.fi',
#  u'mike@cbl.umd.edu',
#  u'mike@kavishar.umd.edu',
#  u'wollman@griffin.uvm.edu',
#  u'dfi@specklec.mpifr',
#  u'baalke@kelvin.jpl.nasa.gov',
#  u'sysmgr@king.eng.umd.edu',
#  u'dante@shakala.com',
#  u'pg@sanitas.stortek.com',
#  u'higgins@fnalf.fnal.gov',
#  u'higgins@fnal.bitnet',
#  u'higgins@fnal.fnal.gov',
#  u'mwilson@ncratl.atlantaga.ncr.com',
#  u'tm@ibm.cl.msu.edu',
#  u'c@news.cso.uiuc.edu',
#  u'rbunge@access.digex.net',
#  u'rbunge@access.digex.com',
#  u'nsmca@aurora.alaska.edu',
#  u'tm@msu.edu',
#  u'nickh@cmu.edu',
#  u'stephens@geod.emr.ca',
#  u'saundrsg@qucdn.queensu.ca',
#  u'saundrsg@qucdn.queensu.ca',
#  u'o@zoo.toronto.edu',
#  u'henry@zoo.toronto.edu',
#  u'henry@zoo.toronto.edu',
#  u'khillig@umich.edu',
#  u'hillig@chem.lsa.umich.edu',
#  u'bruce.scott@launchpad.unc.edu',
#  u'henry@zoo.toronto.edu',
#  u'o@mojo.eng.umd.edu',
#  u'sysmgr@king.eng.umd.edu',
#  u'henry@zoo.toronto.edu',
#  u'rls@uihepa.hep.uiuc.edu',
#  u'daviss@sweetpea.jsc.nasa.gov',
#  u'lhawkins@annie.wellesley.edu',
#  u'lhawkins@lucy.wellesley.edu',
#  u'held at p.m',
#  u'richmond@spiff.princeton.edu',
#  u'qa@ucdavis.edu',
#  u'ended at p.m',
#  u'baalke@kelvin.jpl.nasa.gov',
#  u'baube@optiplan.fi',
#  u'w@angus.mi.org',
#  u'dragon@angus.mi.org',
#  u'kjenks@gothamcity.jsc.nasa.gov',
#  u'nsmca@aurora.alaska.edu',
#  u'nickh@cs.cmu.edu',
#  u'prb@access.digex.com',
#  u'decnet@consrt.rockwell.com',
#  u'dac@brunel.ac.uk',
#  u'nsmca@aurora.alaska.edu',
#  u'higgins@fnal.bitnet',
#  u'higgins@fnal.fnal.gov',
#  u'henry@zoo.toronto.edu',
#  u'hathaway@stsci.edu',
#  u'loss@husky.bloomu.edu',
#  u'nickh@cmu.edu',
#  u'richmond@spiff.princeton.edu',
#  u'henry@zoo.toronto.edu',
#  u'qm@access.digex.net',
#  u'prb@access.digex.net',
#  u'steinly@topaz.ucsc.edu',
#  u'keithh@tplrd.tpl.oz.au',
#  u'palmer@cco.caltech.edu',
#  u'prb@access.digex.com',
#  u'steinly@lick.ucsc.edu',
#  u'shoran@nmsu.edu',
#  u'devdjn@space.alcbel.be',
#  u'f@gargravarr.cc.utexas.edu',
#  u'cohen@ssdgwy.mdc.com',
#  u'chrisj@emx.cc.utexas.edu',
#  u'chrisj@emx.cc.utexas.edu',
#  u'chrisj@emx.cc.utexas.edu',
#  u'tuinstra@sandman.ece.clarkson.edu',
#  u'tuinstrd@craft.camp.clarkson.edu',
#  u'goltz@mimi.uu.net',
#  u'henry@zoo.toronto.edu',
#  u'msb@sq.sq.com',
#  u'msb@sq.com',
#  u'jscotti@lpl.arizona.edu',
#  u'baalke@kelvin.jpl.nasa.gov',
#  u'dietz@cs.rochester.edu',
#  u'dietz@cs.rochester.edu',
#  u'steinly@topaz.ucsc.edu',
#  u'steinly@lick.ucsc.edu',
#  u'pyron@skndiv.dseg.ti.com',
#  u'nsmca@aurora.alaska.edu',
#  u'w@theporch.raider.net',
#  u'gene@theporch.raider.net',
#  u'gene@theporch.raider.net',
#  u'pyron@skndiv.dseg.ti.com',
#  u'pyron@skndiv.dseg.ti.com',
#  u'jfw@ksr.com',
#  u'nanderso@endor.sim.es.com',
#  u'jmcocker@eos.ncsu.edu',
#  u'pyron@skndiv.dseg.ti.com',
#  u'nicho@vnet.ibm.com',
#  u'nicho@olympus.demon.co.uk',
#  u'jpw@cbis.ece.drexel.edu',
#  u'rostamian@umbc.bitnet',
#  u'rouben@math.umbc.edu',
#  u'rostamian@umbc.bitnet',
#  u'rouben@math.umbc.edu',
#  u'nsmca@aurora.alaska.edu',
#  u'shag@aerospace.aero.org',
#  u'wingert@vnet.ibm.com',
#  u'wingert@vnet.ibm.com',
#  u'palmer@cco.caltech.edu',
#  u'prb@access.digex.com',
#  u'jhwitten@cs.ruu.nl',
#  u'baalke@kelvin.jpl.nasa.gov',
#  u'baalke@kelvin.jpl.nasa.gov',
#  u'baalke@kelvin.jpl.nasa.gov',
#  u'nsmca@aurora.alaska.edu',
#  u'feulner@qmlink.draper.com',
#  u'mccall@mksol.dseg.ti.com',
#  u'bday@lambda.msfc.nasa.gov',
#  u'rdouglas@stsci.edu',
#  u'rdouglas@stsci.edu',
#  u'pjc@jet.uk',
#  u'vamwendt@upei.ca',
#  u'cain@geomag.gly.fsu.edu',
#  u'cain@fsu.bitnet',
#  u'c.o.egalon@larc.nasa.gov',
#  u'tkelso@afit.af.mil',
#  u'hhi@zoo.toronto.edu',
#  u'henry@zoo.toronto.edu',
#  u'davem@ee.ubc.ca',
#  u'wiml@u.washington.edu',
#  u'tz@zoo.toronto.edu',
#  u'mccall@mksol.dseg.ti.com',
#  u'henry@zoo.toronto.edu',
#  u'wingert@vnet.ibm.com',
#  u'tz@zoo.toronto.edu',
#  u'tz@zoo.toronto.edu',
#  u'mccall@mksol.dseg.ti.com',
#  u'klaes@verga.enet.dec.com',
#  u'weemba@libra.wistar.upenn.edu',
#  u'yamada@yscvax.ysc.go.jp',
#  u'klaes@verga.enet.dec.com',
#  u'fian@sovam.com',
#  u'ldaddari@nrao.edu',
#  u'thomsonal@cpva.saic.com',
#  u'henry@zoo.toronto.edu',
#  u'isaackuo@math.berkeley.edu',
#  u'higgins@fnalf.fnal.gov',
#  u'eugene@orville.nas.nasa.gov',
#  u'cchung@phy.duke.edu',
#  u'bill@xpresso.uucp',
#  u'scott@psy.uwa.oz.au',
#  u'nether@wpi.wpi.edu',
#  u's.fd@zoo.toronto.edu',
#  u'henry@zoo.toronto.edu',
#  u'baalke@kelvin.jpl.nasa.gov',
#  u'jgreen@oboe.calpoly.edu',
#  u'palmer@cco.caltech.edu',
#  u'prb@access.digex.com',
#  u'in@hermes.hrz.uni',
#  u'hoover@mathematik.uni',
#  u'enzo@research.canon.oz.au',
#  u'fred.mccall@dseg.ti.com',
#  u'hoover@mathematik.uni',
#  u'enzo@research.canon.oz.au',
#  u'nsmca@aurora.alaska.edu',
#  u'henry@zoo.toronto.edu',
#  u'ward@pashosh.wisdom.weizmann.ac.il',
#  u'jgladu@bcm.tmc.edu',
#  u'aws@iti.org',
#  u'henry@zoo.toronto.edu',
#  u'steinly@topaz.ucsc.edu',
#  u'dietz@cs.rochester.edu',
#  u'steinly@lick.ucsc.edu',
#  u'r@panix.com',
#  u'dannyb@panix.com',
#  u'henry@zoo.toronto.edu',
#  u'veikko.makela@helsinki.fi',
#  u'higgins@fnalf.fnal.gov',
#  u'do@bigboote.wpi.edu',
#  u'wfbrown@wpi.wpi.edu',
#  u'wfbrown@wpi.wpi.edu',
#  u'xugl.jow@skates.gsfc.nasa.gov',
#  u'xrcjd@mudpuppy.gsfc.nasa.gov',
#  u'dmcaloon@tuba.calpoly.edu',
#  u'zj.hhq@murdoch.acc.virginia.edu',
#  u'aqr$dnv@access.digex.net',
#  u'prb@access.digex.com',
#  u'nicho@vnet.ibm.com',
#  u'nicho@olympus.demon.co.uk',
#  u'$beo@hsc.usc.edu',
#  u'khayash@hsc.usc.edu',
#  u'u@access.digex.net',
#  u'prb@access.digex.com',
#  u'mccall@mksol.dseg.ti.com',
#  u'fred.mccall@dseg.ti.com',
#  u'mccall@mksol.dseg.ti.com',
#  u'fred.mccall@dseg.ti.com',
#  u'atae@spva.ph.ic.ac.uk',
#  u'fred.mccall@dseg.ti.com',
#  u'jdnicoll@prism.ccs.uwo.ca',
#  u'un.bpq@zoo.toronto.edu',
#  u'henry@zoo.toronto.edu',
#  u'keithley@apple.com',
#  u'victor@inqmind.bison.mb.ca',
#  u'gnb@baby.bby.com.au',
#  u'lr.kxf@news.cso.uiuc.edu',
#  u'gnb@bby.com.au',
#  u'y.mkk@raistlin.udev.cdc.com',
#  u'pbd@runyon.cim.cdc.com',
#  u'henry@zoo.toronto.edu',
#  u'v@techbook.techbook.com',
#  u'dant@techbook.techbook.com',
#  u'hathaway@stsci.edu',
#  u'greer@utdcss.utdallas.edu',
#  u'jhart@agora.rain.com',
#  u'jhart@agora.rain.com',
#  u'len@math.nwu.edu',
#  u'request@isu.isunet.edu',
#  u'request@telesoft.com',
#  u'request@esseye.si.com',
#  u'vac@cs.cmu.edu',
#  u'request@cs.cmu.edu',
#  u'baalke@kelvin.jpl.nasa.gov',
#  u'wollman@uvm.edu',
#  u'veikko.makela@helsinki.fi',
#  u'henry@zoo.toronto.edu',
#  u'ronnie@cisco.com',
#  u'don@chara.gsu.edu',
#  u'sjeyasin@axion.bt.co.uk',
#  u'rbunge@access.digex.com',
#  u'yee@ames.arc.nasa.gov',
#  u'baalke@kelvin.jpl.nasa.gov',
#  u'tkelso@blackbird.afit.af.mil',
#  u'mrose@stsci.edu',
#  u'j.jahn@abbs.hanse.de',
#  u'lang@unb.ca',
#  u'oler@hg.uleth.ca',
#  u'glennc@cs.sfu.ca',
#  u'aws@iti.org',
#  u'baalke@kelvin.jpl.nasa.gov',
#  u'mcdowell@cfa.harvard.edu',
#  u'freed@nss.fidonet.org',
#  u'tkelso@afit.af.mil',
#  u'mccolm@darwin.math.usf.edu',
#  u'as@rice.edu',
#  u'conor@owlnet.rice.edu',
#  u'k@suntan.eng.usf.edu',
#  u'mccolm@darwin.math.usf.edu',
#  u'saundrsg@qucdn.queensu.ca',
#  u'saundrsg@qucdn.queensu.ca',
#  u'nickh@cmu.edu',
#  u'kjenks@gothamcity.jsc.nasa.gov',
#  u'hrubin@snap.stat.purdue.edu',
#  u'palmer@sfu.ca',
#  u'urf@icl.se',
#  u'wdwells@nyx.cs.du.edu',
#  u'matthew@phantom.gatech.edu',
#  u'jlieb@is.morgan.com',
#  u'baalke@kelvin.jpl.nasa.gov',
#  u'kjenks@gothamcity.jsc.nasa.gov',
#  u'djf@uk.ac.cov.cck',
#  u'sg@news.cso.uiuc.edu',
#  u'rdouglas@stsci.edu',
#  u'tkelso@afit.af.mil',
#  u'mccall@mksol.dseg.ti.com',
#  u'kjenks@gothamcity.jsc.nasa.gov',
#  u'ktj@beach.cis.ufl.edu',
#  u'dante@shakala.com',
#  u'tm@ibm.cl.msu.edu',
#  u'sysmgr@king.eng.umd.edu',
#  u'henry@zoo.toronto.edu',
#  u'sysmgr@cadlab.eng.umd.edu',
#  u'rborden@ugly.uvic.ca',
#  u'prb@access.digex.com',
#  u'rborden@ra.uvic.ca',
#  u'rivan@bnr.ca',
#  u'shafer@rigel.dfrf.nasa.gov',
#  u'rhoc.fty@news.cso.uiuc.edu',
#  u'higgins@fnal.bitnet',
#  u'higgins@fnal.fnal.gov',
#  u'enzo@research.canon.oz.au',
#  u'friday at p.m',
#  u'dietz@cs.rochester.edu',
#  u'will@rins.ryukoku.ac.jp',
#  u'dietz@cs.rochester.edu',
#  u'b@zoo.toronto.edu',
#  u'henry@zoo.toronto.edu',
#  u'willner@cfa.harvard.edu',
#  u'lpf@uunet.uu.net',
#  u'w.bur@zoo.toronto.edu',
#  u'henry@zoo.toronto.edu',
#  u'radsr$att@access.digex.net',
#  u'prb@access.digex.com',
#  u'dietz@cs.rochester.edu',
#  u'henry@zoo.toronto.edu',
#  u'aws@iti.org',
#  u'keithley@apple.com',
#  u'swoithe@crackle.aelmg.adelaide.edu.au',
#  u'decnet@consrt.rockwell.com',
#  u'jeff.cook@ftcollinsco.ncr.com',
#  u'jeff.cook@ftcollinsco.ncr.com',
#  u'held at p.m',
#  u'nsmca@aurora.alaska.edu',
#  u'stephens@geod.emr.ca',
#  u'ethanb@ptolemy.astro.washington.edu',
#  u'keithh@tplrd.tpl.oz.au',
#  u'palmer@cco.caltech.edu',
#  u'prb@access.digex.com',
#  u'alien@acheron.amigans.gen.nz',
#  u'stephens@geod.emr.ca',
#  u'j@mojo.eng.umd.edu',
#  u'sysmgr@king.eng.umd.edu',
#  u'j@mojo.eng.umd.edu',
#  u'sysmgr@king.eng.umd.edu',
#  u'steinly@topaz.ucsc.edu',
#  u'steinly@lick.ucsc.edu',
#  u'ftpmail@decwrl.dec.com',
#  u'bitftp@pucc.princeton.edu',
#  u'server@ames.arc.nasa.gov',
#  u'yee@ames.arc.nasa.gov',
#  u'ads@cuads.coloradu.edu',
#  u'stern@cfa.harvard.edu',
#  u'newsdesk@jplpost.jpl.nasa.gov',
#  u'm.l.nelson@larc.nasa.gov',
#  u'admin@techreports.larc.nasa.gov',
#  u"'request@nssdc.gsfc.nasa.gov",
#  u'request@nssdca.gsfc.nasa.gov',
#  u'reppert@stsci.edu',
#  u'odea@stsci.edu',
#  u'bpirenne@eso.org',
#  u'wayne@csri.utoronto.ca',
#  u'jdishaw@hmcvax.claremont.edu',
#  u'downey@tasha.cca.cr.rockwell.com',
#  u'davy@ecn.purdue.edu',
#  u'terry@venus.sunquest.com',
#  u'bankst@kauri.vuw.ac.nz',
#  u'landsman@stars.gsfc.nasa.gov',
#  u'listserv@uga.bitnet',
#  u'stooke@vaxr.sscl.uwo.ca',
#  u'rbunge@access.digex.net',
#  u'agi.mju@news.cso.uiuc.edu',
#  u'bruce.scott@launchpad.unc.edu',
#  u'rdouglas@stsci.edu',
#  u'hathaway@stsci.edu',
#  u'henry@zoo.toronto.edu',
#  u'tm@msu.edu',
#  u'jdnicoll@prism.ccs.uwo.ca',
#  u'tm@msu.edu',
#  u'daviss@sweetpea.jsc.nasa.gov',
#  u're@access.digex.net',
#  u'prb@access.digex.com',
#  u'higgins@fnal.fnal.gov',
#  u'higgins@fnal.bitnet',
#  u'higgins@fnal.bitnet',
#  u'higgins@fnal.fnal.gov',
#  u'spencer@lowell.edu',
#  u'baalke@kelvin.jpl.nasa.gov',
#  u'qo@well.sf.ca.us',
#  u'metares@well.sf.ca.us',
#  u'q@kelvin.seas.virginia.edu',
#  u'bruce.scott@launchpad.unc.edu',
#  u'rsdwg@orion.ossa.hq.nasa.gov',
#  u'xrcjd@resolve.gsfc.nasa.gov',
#  u'xt.iqd@zoo.toronto.edu',
#  u'henry@zoo.toronto.edu',
#  u'r@panix.com',
#  u'dannyb@panix.com',
#  u'rls@uihepa.hep.uiuc.edu',
#  u'mancus@sweetpea.jsc.nasa.gov',
#  u'cook@varmit.mdc.com',
#  u'lazio@astrosun.tn.cornell.edu',
#  u'fcrary@ucsu.colorado.edu',
#  u'fcrary@ucsu.colorado.edu',
#  u'lhawkins@annie.wellesley.edu',
#  u'lazio@astrosun.tn.cornell.edu',
#  u'szabo@techboook.com',
#  u'hb@news.cso.uiuc.edu',
#  u'nsmca@aurora.alaska.edu',
#  u'tffreeba@indyvax.iupui.edu',
#  u'gene@jackatak.raider.net',
#  u'uphrrmk@gemini.oscs.montana.edu',
#  u'dmcaloon@tuba.calpoly.edu',
#  u'henry@zoo.toronto.edu',
#  u'kjenks@gothamcity.jsc.nasa.gov',
#  u'thomsonal@cpva.saic.com',
#  u'mll@aio.jsc.nasa.gov',
#  u'henry@zoo.toronto.edu',
#  u'f@cbl.umd.edu',
#  u'mike@starburst.umd.edu',
#  u'davem@ee.ubc.ca',
#  u'dietz@cs.rochester.edu',
#  u'dietz@cs.rochester.edu',
#  u'steinly@lick.ucsc.edu',
#  u'prb@access.digex.net',
#  u'nicho@vnet.ibm.com',
#  u'nicho@vnet.ibm.com',
#  u'nicho@olympus.demon.co.uk',
#  u'dvgh.aph@news.cso.uiuc.edu',
#  u'prb@access.digex.net',
#  u'prb@access.digex.net',
#  u'gene@theporch.raider.net',
#  u'tm@ibm.cl.msu.edu',
#  u'z@zoo.toronto.edu',
#  u'henry@zoo.toronto.edu',
#  u'w@theporch.raider.net',
#  u'gene@theporch.raider.net',
#  u'gnb@bby.com.au',
#  u'prb@access.digex.com',
#  u'h@netcom.com',
#  u'billosh@netcom.com',
#  u'dennisn@ecs.comm.mot.com',
#  u'jgreen@trumpet.calpoly.edu',
#  u'khayash@hsc.usc.edu',
#  u'kjenks@gothamcity.jsc.nasa.gov',
#  u'cohen@ssdgwy.mdc.com',
#  u'prb@access.digex.com',
#  u'baalke@kelvin.jpl.nasa.gov',
#  u'baalke@kelvin.jpl.nasa.gov',
#  u'jcobban@bnr.ca',
#  u'swf@elsegundoca.ncr.com',
#  u'wats@scicom.alphacdc.com',
#  u'msb@sq.sq.com',
#  u'higgins@fnal.fnal.gov',
#  u'higgins@fnal.bitnet',
#  u'mancus@sweetpea.jsc.nasa.gov',
#  u'c.o.egalon@larc.nasa.gov',
#  u'c.o.egalon@larc.nasa.gov',
#  u'jgreen@oboe.calpoly.edu',
#  u'baalke@kelvin.jpl.nasa.gov',
#  u'nsmca@aurora.alaska.edu',
#  u'nsmca@aurora.alaska.edu',
#  u'prb@access.digex.com',
#  u'tkelso@afit.af.mil',
#  u'ai@news.umbc.edu',
#  u'davem@ee.ubc.ca',
#  u'f@cbl.umd.edu',
#  u'mike@starburst.umd.edu',
#  u'shafer@rigel.dfrf.nasa.gov',
#  u'prb@access.digex.com',
#  u'nsmca@aurora.alaska.edu',
#  u'shafer@rigel.dfrf.nasa.gov',
#  u'nsmca@aurora.alaska.edu',
#  u'shafer@rigel.dfrf.nasa.gov',
#  u'kjenks@gothamcity.jsc.nasa.gov',
#  u'kjenks@gothamcity.jsc.nasa.gov',
#  u'kjenks@gothamcity.jsc.nasa.gov',
#  u'nicho@vnet.ibm.com',
#  u'nicho@vnet.ibm.com',
#  u'nicho@olympus.demon.co.uk',
#  u'tm@msu.edu',
#  u'fred.mccall@dseg.ti.com',
#  u'pyron@skndiv.dseg.ti.com',
#  u'sysmgr@cadlab.eng.umd.edu',
#  u'prb@access.digex.com',
#  u'e@news.cso.uiuc.edu',
#  u'nicho@vnet.ibm.com',
#  u'nicho@olympus.demon.co.uk',
#  u'm@xpresso.uucp',
#  u'bill@xpresso.uucp',
#  u'henry@zoo.toronto.edu',
#  u'higgins@fnalf.fnal.gov',
#  u'palmer@sfu.ca',
#  u'henry@zoo.toronto.edu',
#  u'nsmca@aurora.alaska.edu',
#  u'almo@packmind.ebay.sun.com',
#  u'henry@zoo.toronto.edu',
#  u'c.o.egalon@larc.nasa.gov',
#  u'c.o.egalon@larc.nasa.gov',
#  u'c.o.egalon@larc.nasa.gov',
#  u'schumach@convex.com',
#  u'prb@access.digex.net',
#  u'khayash@hsc.usc.edu',
#  u'baalke@kelvin.jpl.nasa.gov',
#  u'pyron@skndiv.dseg.ti.com',
#  u'pyron@skndiv.dseg.ti.com',
#  u'jpw@cbis.ece.drexel.edu',
#  u'asimov@nas.nasa.gov',
#  u'paulc@mri.com',
#  u'henry@zoo.toronto.edu',
#  u'sg@news.cso.uiuc.edu',
#  u'hathaway@stsci.edu',
#  u'i@access.digex.net',
#  u'prb@access.digex.net',
#  u'nhg@rpi.edu',
#  u'strider@clotho.acm.rpi.edu',
#  u'kjenks@gothamcity.jsc.nasa.gov',
#  u'kjenks@gothamcity.jsc.nasa.gov',
#  u'webb@tsavo.hks.com',
#  u'webb@hks.com',
#  u'klaes@verga.enet.dec.com',
#  u'crawford@noao.edu',
#  u'klaes@verga.enet.dec.com',
#  u'verga.dec@decwrl.enet.dec.com',
#  u'verga.enet.dec.com@uunet.uu.net',
#  u'kjenks@gothamcity.jsc.nasa.gov',
#  u'flb@flb.optiplan.fi',
#  u'kjenks@gothamcity.jsc.nasa.gov',
#  u'aws@iti.org',
#  u'henry@zoo.toronto.edu',
#  u'keithley@apple.com',
#  u'nickh@cmu.edu',
#  u'aws@iti.org',
#  u'jgreen@trumpet.calpoly.edu',
#  u'pete@extro.su.oz.au',
#  u'steinly@topaz.ucsc.edu',
#  u'innjkv@gap.caltech.edu',
#  u'jafoust@cco.caltech.edu',
#  u'jdnicoll@prism.ccs.uwo.ca',
#  u'a.gzx@news.cso.uiuc.edu',
#  u'aws@iti.org',
#  u'nicho@vnet.ibm.com',
#  u'nicho@olympus.demon.co.uk',
#  u'fcrary@ucsu.colorado.edu',
#  u't.fph@cunews.carleton.ca',
#  u'wcsbeau@superior.carleton.ca',
#  u'nsmca@aurora.alaska.edu',
#  u'djf@uk.ac.cov.cck',
#  u'nsmca@aurora.alaska.edu',
#  u'w@theporch.raider.net',
#  u'gene@theporch.raider.net',
#  u'gene@theporch.raider.net',
#  u'cam@hawk.adied.oz.au',
#  u'etoyoc@leland.stanford.edu',
#  u'thierry@sycom.mi.org',
#  u'stange@meena.cc.uregina.ca',
#  u'w@inqmind.bison.mb.ca',
#  u'victor@inqmind.bison.mb.ca',
#  u'victor@inqmind.bison.mb.ca',
#  u'jgreen@oboe.calpoly.edu',
#  u'mju@zoo.toronto.edu',
#  u'henry@zoo.toronto.edu',
#  u'm@xpresso.uucp',
#  u'bill@xpresso.uucp',
#  u'henry@zoo.toronto.edu',
#  u'tff@plato.ds.boeing.com',
#  u'tff@plato.ds.boeing.com',
#  u'reinnonl@phantom.gatech.edu',
#  u'matthew@phantom.gatech.edu',
#  u'will@rins.ryukoku.ac.jp',
#  u'fred.mccall@dseg.ti.com',
#  u'dietz@cs.rochester.edu',
#  u'mccall@mksol.dseg.ti.com',
#  u'fred.mccall@dseg.ti.com',
#  u'pbd@runyon.cim.cdc.com',
#  u'higgins@fnal.bitnet',
#  u'higgins@fnal.fnal.gov',
#  u'y.mkk@raistlin.udev.cdc.com',
#  u'pbd@runyon.cim.cdc.com',
#  u'rjungcla@ihlpb.att.com',
#  u'fcrary@ucsu.colorado.edu',
#  u'pkc$ovf@almaak.usc.edu',
#  u'ajayshah@almaak.usc.edu',
#  u'higgins@fnalf.fnal.gov',
#  u'sysmgr@cadlab.eng.umd.edu',
#  u'baalke@kelvin.jpl.nasa.gov',
#  u'jgreen@oboe.calpoly.edu',
#  u'c.h.a.wong@bradford.ac.uk',
#  u'fred.mccall@dseg.ti.com',
#  u'sdd@larc.nasa.gov',
#  u'prb@access.digex.net',
#  u's.d.derry@larc.nasa.gov',
#  u'kjenks@gothamcity.jsc.nasa.gov',
#  u'gene@theporch.raider.net',
#  u'kjenks@gothamcity.jsc.nasa.gov',
#  u'tm@ibm.cl.msu.edu',
#  u'baalke@kelvin.jpl.nasa.gov',
#  u'todd@phad.la.locus.com',
#  u'nickh@cmu.edu',
#  u'aws@iti.org',
#  u'cspara.decnet@fedex.msfc.nasa.gov',
#  u'sysmgr@king.eng.umd.edu',
#  u'kjenks@gothamcity.jsc.nasa.gov',
#  u'sysmgr@cadlab.eng.umd.edu',
#  u's@access.digex.net',
#  u'prb@access.digex.com',
#  u'baalke@kelvin.jpl.nasa.gov',
#  u'cain@geomag.gly.fsu.edu',
#  u'cain@fsu.bitnet',
#  u'cosmic@uga.bitnet',
#  u'baalke@kelvin.jpl.nasa.gov',
#  u'baalke@kelvin.jpl.nasa.gov',
#  u'richmond@astro.princeton.edu',
#  u'w@shakala.com',
#  u'dante@shakala.com',
#  u'jmcocker@eos.ncsu.edu',
#  u'egan@blkbox.com',
#  u'lije@cognito.princeton.edu',
#  u'clarke@acme.ucf.edu',
#  u'jpg@bnr.co.uk',
#  u'khayash@hsc.usc.edu',
#  u'tkelso@afit.af.mil',
#  u'jpg@bnr.co.uk',
#  u'nsmca@aurora.alaska.edu',
#  u'yamada@yscvax.ysc.go.jp',
#  u'jjb@beta.lanl.gov',
#  u'kjenks@gothamcity.jsc.nasa.gov',
#  u'nsmca@aurora.alaska.edu',
#  u'henry@zoo.toronto.edu',
#  u'nsmca@aurora.alaska.edu',
#  u'jericho@uunet.uu.net',
#  u'madison@wam.umd.edu',
#  u'steinly@topaz.ucsc.edu',
#  u'radsr$att@access.digex.net',
#  u'prb@access.digex.com',
#  u'tholen@galileo.ifa.hawaii.edu',
#  u'jib@bonnie.jsc.nasa.gov',
#  u'chico@ccsun.unicamp.br',
#  u'cotuca@ccvax.unicamp.br',
#  u'dnash@uxa.cso.uiuc.edu',
#  u'nsmca@aurora.alaska.edu',
#  u'henry@zoo.toronto.edu',
#  u'baalke@kelvin.jpl.nasa.gov',
#  u'jhwitten@cs.ruu.nl',
#  u'prb@access.digex.com',
#  u'radsr$att@access.digex.net',
#  u'prb@access.digex.com',
#  u'steinly@lick.ucsc.edu',
#  u'keithley@apple.com',
#  u'keithley@apple.com',
#  u'kjenks@jsc.nasa.gov',
#  u'higgins@fnal.bitnet',
#  u'higgins@fnal.fnal.gov',
#  u'shafer@rigel.dfrf.nasa.gov',
#  u'prb@access.digex.com',
#  u'nsmca@aurora.alaska.edu',
#  u'shafer@rigel.dfrf.nasa.gov',
#  u'jbreed@ingr.com',
#  u'henry@zoo.toronto.edu',
#  u'enzo@research.canon.oz.au',
#  u'pearson@tsd.arlut.utexas.edu',
#  u'jpw@cbis.ece.drexel.edu',
#  u'pearson@titan.tsd.arlut.utexas.edu',
#  u'ven@maxwell.physics.purdue.edu',
#  u'neie@purccvm.bitnet',
#  u'$ree@access.digex.net',
#  u'prb@access.digex.com',
#  u'fred.mccall@dseg.ti.com',
#  u'jdnicoll@prism.ccs.uwo.ca',
#  u'jafoust@cco.caltech.edu',
#  u'jgarland@kean.ucs.mun.ca',
#  u'msb@sq.sq.com',
#  u'yamauchi@ces.cwru.edu',
#  u'cohen@ssdgwy.mdc.com',
#  u'kjenks@gothamcity.jsc.nasa.gov',
#  u'rborden@ugly.uvic.ca',
#  u'jim@inqmind.bison.mb.ca',
#  u'tm@ibm.cl.msu.edu',
#  u'nsmca@aurora.alaska.edu',
#  u'gnb@bby.com.au',
#  u'nsmca@aurora.alaska.edu',
#  u'henry@zoo.toronto.edu',
#  u'thomsonal@cpva.saic.com',
#  u'dietz@cs.rochester.edu',
#  u'h@gap.caltech.edu',
#  u'kwp@wag.caltech.edu',
#  u'dietz@cs.rochester.edu',
#  u'jcobban@bnr.ca',
#  u'jcobban@bnr.ca',
#  u'prb@access.digex.net',
#  u'schumach@convex.com',
#  u'jpg@bnr.co.uk',
#  u'snydefj@eng.auburn.edu',
#  u'higgins@fnal.bitnet',
#  u'higgins@fnal.fnal.gov',
#  u'msb@sq.sq.com',
#  u'msb@sq.com',
#  u'rnaih$jvj@access.digex.net',
#  u'prb@access.digex.net',
#  u'dmcaloon@tuba.calpoly.edu',
#  u'fred.mccall@dseg.ti.com',
#  u'baube@optiplan.fi',
#  u'metares@well.sf.ca.us',
#  u'henry@zoo.toronto.edu',
#  u'tm@ibm.cl.msu.edu',
#  u'gene@theporch.raider.net',
#  u'q@well.sf.ca.us',
#  u'collins@well.sf.ca.us',
#  u'henry@zoo.toronto.edu',
#  u'mcrandall@eagle.wesleyan.edu',
#  u'turner@bigbang.astro.indiana.edu',
#  u'turner@bigbang.astro.indiana.edu',
#  u'agae@lle.rochester.edu',
#  u'matthew@phantom.gatech.edu',
#  u'wdwells@nyx.cs.du.edu',
#  u'palmer@alumni.caltech.edu',
#  u'palmer@tgrs.gsfc.nasa.gov',
#  u'j@mojo.eng.umd.edu',
#  u'sysmgr@king.eng.umd.edu',
#  u'henry@zoo.toronto.edu',
#  u'djf@uk.ac.cov.cck',
#  u'jeff.cook@ftcollinsco.ncr.com',
#  u'enzo@research.canon.oz.au',
#  u'tm@msu.edu',
#  u'henry@zoo.toronto.edu',
#  u'zwork@starfighter.den.mmc.com',
#  u'henry@zoo.toronto.edu',
#  u'roeber@cern.ch',
#  u'roeber@caltech.edu',
#  u'sysmgr@king.eng.umd.edu',
#  u'henry@zoo.toronto.edu',
#  u'sysmgr@king.eng.umd.edu',
#  u'sysmgr@cadlab.eng.umd.edu',
#  u'asa@chara.gsu.edu',
#  u'klaes@verga.enet.dec.com',
#  u'verga.dec@decwrl.enet.dec.com',
#  u'verga.enet.dec.com@uunet.uu.net',
#  u'site at chara.gsu.edu',
#  u'nicho@vnet.ibm.com',
#  u'jmcocker@eos.ncsu.edu',
#  u'hb$kbi@access.digex.net',
#  u'prb@access.digex.com',
#  u'nsmca@aurora.alaska.edu',
#  u'prb@access.digex.com',
#  u'sysmgr@king.eng.umd.edu',
#  u'wdwells@esprit.uccs.edu',
#  u'prb@access.digex.com',
#  u'rborden@ra.uvic.ca',
#  u'gene@theporch.raider.net',
#  u'kjenks@gothamcity.jsc.nasa.gov',
#  u'bill@xpresso.uucp',
#  u'jeff.cook@ftcollinsco.ncr.com',
#  u'jeff.cook@ftcollinsco.ncr.com',
#  u'enzo@research.canon.oz.au',
#  u'enzo@research.canon.oz.au',
#  u'jeff.cook@ftcollinsco.ncr.com',
#  u'palmer@cco.caltech.edu',
#  u'b@agate.berkeley.edu',
#  u'ghelf@violet.berkeley.edu',
#  u'adam@paix.sw.stratus.com',
#  u'prb@access.digex.com',
#  u'pyron@skndiv.dseg.ti.com',
#  u'prb@access.digex.com',
#  u'pyron@skndiv.dseg.ti.com',
#  u'henry@zoo.toronto.edu',
#  u'nsmca@aurora.alaska.edu',
#  u'kwp@wag.caltech.edu',
#  u'abdkw@stdvax.gsfc.nasa.gov',
#  u'baalke@kelvin.jpl.nasa.gov',
#  u'agc@bnr.ca',
#  u'alan@gid.co.uk',
#  u'nickh@cs.cmu.edu',
#  u'agi.mju@news.cso.uiuc.edu',
#  u'prb@access.digex.net',
#  u'z@zoo.toronto.edu',
#  u'henry@zoo.toronto.edu',
#  u'palmer@alumni.caltech.edu',
#  u'palmer@tgrs.gsfc.nasa.gov',
#  u'rdouglas@stsci.edu',
#  u'bday@lambda.msfc.nasa.gov',
#  u'freed@nss.org',
#  u'sysmgr@cadlab.eng.umd.edu',
#  u'aj@access.digex.net',
#  u'prb@access.digex.com',
#  u'pjc@jet.uk',
#  u'e@access.digex.com',
#  u'prb@access.digex.com',
#  u'jaskew@spam.maths.adelaide.edu',
#  u'to$oh@access.digex.net',
#  u'prb@access.digex.com',
#  u'dennisn@ecs.comm.mot.com',
#  u'prb@access.digex.com',
#  u'snydefj@eng.auburn.edu',
#  u'listserv@uga.cc.uga.edu',
#  u'listserv@finhuc.hut.fi',
#  u'request@isu.isunet.edu',
#  u'space@isu.isunet.edu',
#  u'request@isu.isunet.edu',
#  u'mwm@cmu.edu',
#  u'hansk@aie.nl',
#  u'shafer@rigel.dfrf.nasa.gov',
#  u'e@visix.com',
#  u'dan@visix.com',
#  u'located at ames.arc.nasa.gov',
#  u'henry@zoo.toronto.edu',
#  u'dragon@angus.mi.org',
#  u'schumach@convex.com',
#  u's.d.derry@larc.nasa.gov',
#  u'prb@access.digex.net',
#  u's.d.derry@larc.nasa.gov',
#  u'will@rins.ryukoku.ac.jp',
#  u'matthew@phantom.gatech.edu',
#  u'msmilor@skat.usc.edu',
#  u'smilor@aludra.usc.edu',
#  u'yamauchi@alpha.ces.cwru.edu',
#  u'wheate@uncamult.bitnet',
#  u'chrisj@emx.cc.utexas.edu',
#  u'higgins@fnalf.fnal.gov',
#  u'snydefj@eng.auburn.edu',
#  u'jgladu@bcm.tmc.edu',
#  u'ward@pashosh.wisdom.weizmann.ac.il',
#  u'fred.mccall@dseg.ti.com',
#  u'shag@aero.org',
#  u'baalke@kelvin.jpl.nasa.gov',
#  u'request@isu.isunet.edu',
#  u'mwm@cmu.edu',
#  u'rick@trystro.uucp',
#  u'hausner@qucis.queensu.ca',
#  u'dant@techbook.com',
#  u'pkc$ovf@almaak.usc.edu',
#  u'ajayshah@almaak.usc.edu',
#  u'henry@zoo.toronto.edu',
#  u'tm@ibm.cl.msu.edu',
#  u'dennisn@ecs.comm.mot.com',
#  u'jgreen@trumpet.calpoly.edu',
#  u'dennisn@ecs.comm.mot.com',
#  u'fred.mccall@dseg.ti.com',
#  u'prb@access.digex.com',
#  u'palmer@alumni.caltech.edu',
#  u'palmer@tgrs.gsfc.nasa.gov',
#  u'uy@zoo.toronto.edu',
#  u'henry@zoo.toronto.edu',
#  u'clarke@acme.ucf.edu',
#  u'zellner@stsci.edu',
#  u'nicho@vnet.ibm.com',
#  u'edm@twisto.compaq.com',
#  u'nickh@cs.cmu.edu',
#  u'wdwells@nyx.cs.du.edu',
#  u'wats@scicom.alphacdc.com',
#  u'moses@pan.arc.nasa.gov',
#  u'henry@zoo.toronto.edu',
#  u'decnet@beach.rockwell.com',
#  u'decnet@consrt.rockwell.com',
#  u'bigfoot@sequent.com',
#  u'mccall@mksol.dseg.ti.com',
#  u'$jbk@access.digex.net',
#  u'prb@access.digex.com',
#  u'higgins@fnalf.fnal.gov',
#  u'jennise@dgi.com',
#  u'msb@sq.sq.com',
#  u'jgarland@kean.ucs.mun.ca',
#  u'x@world.std.com',
#  u'vis@world.std.com',
#  u'wats@scicom.alphacdc.com',
#  u'nsmca@aurora.alaska.edu',
#  u'dac@brunel.ac.uk',
#  u'wallacen@cs.colostate.edu',
#  u'jbreed@doink.b',
#  u'uy@zoo.toronto.edu',
#  u'henry@zoo.toronto.edu',
#  u'c.o.egalon@larc.nasa.gov',
#  u'c.o.egalon@larc.nasa.gov',
#  u's@access.digex.net',
#  u'prb@access.digex.com',
#  u'baalke@kelvin.jpl.nasa.gov',
#  u'nsmca@aurora.alaska.edu',
#  u'henry@zoo.toronto.edu',
#  u'kjenks@gothamcity.jsc.nasa.gov',
#  u'prb@access.digex.com',
#  u'will@rins.ryukoku.ac.jp',
#  u'dietz@cs.rochester.edu',
#  u'kjenks@gothamcity.jsc.nasa.gov',
#  u'g@telesoft.com',
#  u'saundrsg@qucdn.queensu.ca',
#  u'saundrsg@qucdn.queensu.ca',
#  u'k@netcom.com',
#  u'geoffm@netcom.com',
#  u'pgf@space.mit.edu',
#  u'cnp@morrow.stanford.edu',
#  u'me.dmg@forsythe.stanford.edu',
#  u'sugarman@cs.umb.edu',
#  u'nanderso@endor.sim.es.com',
#  u'lazio@astrosun.tn.cornell.edu',
#  u'jfc@athena.mit.edu',
#  u'jfc@athena.mit.edu',
#  u'jbatka@desire.wright.edu',
#  u'lazio@astrosun.tn.cornell.edu',
#  u'batkaj@ccmail.dayton.saic.com',
#  u'jbatka@desire.wright.edu',
#  u'nanderso@endor.sim.es.com',
#  u'jmcocker@eos.ncsu.edu',
#  u'dietz@cs.rochester.edu',
#  u'prb@access.digex.com',
#  u'aii$ivs@access.digex.net',
#  u'jgreen@trumpet.calpoly.edu',
#  u'clj@ksr.com',
#  u'gkm@cc.uow.edu.au',
#  u'mancus@sweetpea.jsc.nasa.gov',
#  u'cook@varmit.mdc.com',
#  u'mancus@butch.jsc.nasa.gov',
#  u'mancus@sweetpea.jsc.nasa.gov',
#  u'saundrsg@qucdn.queensu.ca',
#  u'peterf@oddjob.uchicago.edu',
#  u'wallacen@cs.colostate.edu',
#  u'mccall@mksol.dseg.ti.com',
#  u'dmcaloon@tuba.calpoly.edu',
#  u'alien@acheron.amigans.gen.nz',
#  u'rborden@ugly.uvic.ca',
#  u'friday at p.m',
#  u'baalke@kelvin.jpl.nasa.gov',
#  u'schumach@convex.com',
#  u'matthew@phantom.gatech.edu',
#  u'bday@lambda.msfc.nasa.gov',
#  u'rdouglas@stsci.edu',
#  u'garym@alsys.com',
#  u'saundrsg@qucdn.queensu.ca',
#  u'peterf@oddjob.uchicago.edu',
#  u'karl@vnet.ibm.com',
#  u'kkobayas@husc.harvard.edu',
#  u'kkobayas@husc.harvard.edu',
#  u'fairfiel@helios.usq.edu.au',
#  u'lpham@eis.calstate.edu',
#  u'fairfiel@zeus.usq.edu.au',
#  u'jelson@rcnext.cso.uiuc.edu',
#  ...]

# %% [markdown]
# <p style="color:blue">
# Download stopwords
# </p>

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Arkantos\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopset = set(stopwords.words('english'))

# %% [markdown]
# <p style="color:blue">
# Add emails to stopwords. Add a few more words that can be filtered out (This list will be updated later)
# </p>

# %%
stopset.update(emails)
stopset.update(['edu', 'com', 'gov','gmt', 'nntp','net','mil','aa','fri', 'apr','henry','ll',
                'aan','de','deze',
                'sunday', 'monday','tuesday', 'wednesday','thursday', 'friday, saturday'])

# %% [markdown]
# <h4>TF-IDF Vectorizing</h4>
# <p style="color:blue">
# Converting each document in 'cleancorpus' into a sparse matrix 'X' of TFIDF Features
# </p>

# %%
vectorizer = TfidfVectorizer(stop_words=stopset,
                                 use_idf=True, ngram_range=(1, 3))
X = vectorizer.fit_transform(cleancorpus)

# %%
X[0]
# Out:
# <1x228715 sparse matrix of type '<type 'numpy.float64'>'
# 	with 191 stored elements in Compressed Sparse Row format>

# %% [markdown]
# <p style="color:blue">
# Let us peek at the first sparse martix
# </p>

# %%
print X[0]
# Out:
#   (0, 69378)	0.0575151178149
#   (0, 44938)	0.0575151178149
#   (0, 53743)	0.0588071478322
#   (0, 224767)	0.0588071478322
#   (0, 222147)	0.0588071478322
#   (0, 111801)	0.0588071478322
#   (0, 31115)	0.0588071478322
#   (0, 32964)	0.0588071478322
#   (0, 148169)	0.0588071478322
#   (0, 225194)	0.0588071478322
#   (0, 88180)	0.0588071478322
#   (0, 180512)	0.0588071478322
#   (0, 13831)	0.0588071478322
#   (0, 101477)	0.0588071478322
#   (0, 5509)	0.0595113814479
#   (0, 172440)	0.0836667920996
#   (0, 55885)	0.0836667920996
#   (0, 19959)	0.0836667920996
#   (0, 75132)	0.0836667920996
#   (0, 30519)	0.0836667920996
#   (0, 113002)	0.0836667920996
#   (0, 195239)	0.0836667920996
#   (0, 184414)	0.0836667920996
#   (0, 160851)	0.0836667920996
#   (0, 160426)	0.0836667920996
#   :	:
#   (0, 163879)	0.0403880305219
#   (0, 6125)	0.0270794736434
#   (0, 184436)	0.04749927339
#   (0, 18169)	0.04096179144
#   (0, 184852)	0.0416589244684
#   (0, 74049)	0.0447533111241
#   (0, 30494)	0.143280974277
#   (0, 81253)	0.0875531533149
#   (0, 136937)	0.0621547833315
#   (0, 8493)	0.0386977712065
#   (0, 171087)	0.0771547879881
#   (0, 160326)	0.10602143644
#   (0, 64086)	0.0465100549919
#   (0, 2065)	0.0375467018462
#   (0, 5418)	0.0836667920996
#   (0, 137946)	0.106866351155
#   (0, 152750)	0.0381079847929
#   (0, 20907)	0.064971083221
#   (0, 225874)	0.0176644136253
#   (0, 188179)	0.0370112938535
#   (0, 206487)	0.0748752556661
#   (0, 228643)	0.0762159695859
#   (0, 97724)	0.0675631849985
#   (0, 83765)	0.0836667920996
#   (0, 12186)	0.0195977696292

# %% [markdown]
# <h4>Latent Semantic Analysis</h4>
# <p style="color:blue">
# Decomposing X into three matrics U, S & V
# </p>

# %%
X.shape
# Out:
# (987, 228715)

# %% [markdown]
# <p style="color:blue">
# Dimensionality reduction using Single Value Decomposition (SVD)
# <ul>
# <li> Dimensionality of output: 100(recommended to be 100 by Sklearn Documentation for LSA)</li>
# <li> Number of iterations: 50</li>
# </ul>
# </p>

# %%
lsa = TruncatedSVD(n_components=100, n_iter=50)
lsa.fit(X)
# Out:
# TruncatedSVD(algorithm='randomized', n_components=100, n_iter=50,
#        random_state=None, tol=0.0)

# %% [markdown]
# <p style="color:red">
# The above step will take some time to run. Wait until it completes
# </p>

# %%
lsa.components_[0]
# Out:
# array([ 0.00040268,  0.00040268,  0.00040268, ...,  0.00075217,
#         0.00075217,  0.00075217])

# %% [markdown]
# <p style="color:blue">
# Extract features from the concepts. Modified the original code to store the features in a list 'features'
# </p>

# %%
features = []
terms = vectorizer.get_feature_names()
for i, comp in enumerate(lsa.components_): 
    termsInComp = zip (terms,comp)
    sortedTerms =  sorted(termsInComp, key=lambda x: x[1], reverse=True) [:10]
    print "Concept %d:" % i
    for term in sortedTerms:
        print term[0]
        features.append(term[0])
    print " "
# Out:
# Concept 0:
# space
# would
# nasa
# writes
# like
# article
# one
# shuttle
# alaska
# orbit
#
# Concept 1:
# elements
# afit
# afit af
# updated daily
# af
# celestial bbs
# software also available
# software also
# daily
# current
#
# Concept 2:
# jpl
# baalke
# kelvin jpl
# kelvin jpl nasa
# jpl nasa
# kelvin
# command
# nasa
# comet
# spacecraft
#
# Concept 3:
# alaska
# gene
# nasa
# raider
# acad
# acad alaska
# theporch
# theporch raider
# jpl nasa
# jpl
#
# Concept 4:
# space
# nasa
# earth
# launch
# research
# satellite
# part
# center
# venus
# software
#
# Concept 5:
# space
# shuttle
# mission
# hst
# information
# boost
# going
# station
# years
# data
#
# Concept 6:
# see
# might
# station
# fuel
# end
# sky
# different
# us
# power
# uiuc
#
# Concept 7:
# nasa
# station
# dc
# april
# going
# posting
# umd
# space
# high
# software
#
# Concept 8:
# alaska
# high
# system
# zoo
# zoo toronto
# mars
# spencer
# earth
# like
# toronto
#
# Concept 9:
# overhead
# allen
# reston
# isn
# time
# back
# atmosphere
# wrap
# much
# host
#
# Concept 10:
# space
# us
# access digex
# digex
# power
# many
# anyone
# shuttle
# station
# sky
#
# Concept 11:
# nasa
# overhead
# alaska
# university
# program
# systems
# distribution
# writes
# dennis
# project
#
# Concept 12:
# shuttle
# launch
# mission
# ti
# toronto
# writes article
# option
# nasa
# boost
# planet
#
# Concept 13:
# real
# spacecraft
# give
# first
# idea
# use
# news
# atmosphere
# radio
# done
#
# Concept 14:
# launch
# something
# need
# new
# first
# april
# moon
# put
# big
# might
#
# Concept 15:
# launch
# would
# could
# go
# way
# going
# think
# station
# find
# au
#
# Concept 16:
# toronto
# data
# program
# propulsion
# space
# way
# cost
# jpl
# orbital
# long
#
# Concept 17:
# would
# may
# launch
# moon
# orbit
# flight
# good
# way
# know
# program
#
# Concept 18:
# alaska
# launch
# us
# posting host
# earth
# posting
# host
# april
# one
# going
#
# Concept 19:
# software
# see
# years
# commercial
# toronto
# world
# going
# first
# us
# year
#
# Concept 20:
# launch
# system
# pluto
# shuttle
# well
# distribution
# satellite
# around
# talking
# us
#
# Concept 21:
# space
# using
# sun
# alaska
# solar
# toronto
# moon
# ca
# mars
# nasa
#
# Concept 22:
# flight
# long
# point
# well
# mass
# also
# posting host
# moon
# ether
# every
#
# Concept 23:
# get
# make
# could
# technology
# venus
# software
# jpl
# mission
# try
# go
#
# Concept 24:
# alaska
# sky
# flight
# data
# could
# make
# also
# re
# first
# actually
#
# Concept 25:
# launch
# lunar
# need
# money
# posting
# go
# find
# commercial
# observatory
# sky
#
# Concept 26:
# nasa
# orbit
# solar
# data
# shuttle
# ftp
# market
# satellite
# also
# sun
#
# Concept 27:
# pat
# see
# satellites
# able
# commercial
# pluto
# writes
# long
# spencer
# jpl
#
# Concept 28:
# ca
# telescope
# system
# since
# hst
# solar
# station
# say
# article
# space
#
# Concept 29:
# data
# research
# project
# light
# least
# part
# things
# toronto
# au
# even
#
# Concept 30:
# one
# would
# moon
# us
# science
# orbit
# without
# part
# earth
# flight
#
# Concept 31:
# space
# two
# pat
# back
# different
# high
# like
# probe
# part
# re
#
# Concept 32:
# see
# moon
# hst
# software
# vax
# long
# shuttle
# even
# might
# sky
#
# Concept 33:
# moon
# time
# us
# see
# look
# done
# space
# would
# problem
# well
#
# Concept 34:
# us
# mission
# access
# ti
# pat
# need
# right
# problem
# hst
# might
#
# Concept 35:
# would
# year
# people
# around
# moon
# mars
# think
# help
# probes
# system
#
# Concept 36:
# earth
# large
# program
# think
# also
# want
# hst
# two
# alaska
# toronto
#
# Concept 37:
# moon
# re
# sky
# program
# two
# right
# new
# something
# use
# planet
#
# Concept 38:
# earth
# year
# work
# space
# make
# shuttle
# even
# spencer
# solar system
# real
#
# Concept 39:
# see
# also
# spacecraft
# billion
# dc
# flight
# shuttle
# one
# get
# moon
#
# Concept 40:
# moon
# need
# access
# put
# work
# would
# orbit
# world
# data
# software
#
# Concept 41:
# one
# world
# sky
# sun
# new
# data
# things
# alaska
# distribution
# re
#
# Concept 42:
# use
# system
# nasa
# well
# world
# launch
# solar
# government
# good
# lunar
#
# Concept 43:
# solar
# research
# far
# way
# host
# sky
# first
# shuttle
# zoo
# zoo toronto
#
# Concept 44:
# distribution
# something
# man
# government
# even
# want
# costs
# made
# posting host
# news
#
# Concept 45:
# pat
# us
# alaska
# one
# go
# research
# since
# point
# part
# design
#
# Concept 46:
# power
# idea
# well
# would
# mission
# say
# used
# better
# make
# money
#
# Concept 47:
# shuttle
# make
# could
# anyone
# see
# think
# alaska
# much
# news
# way
#
# Concept 48:
# new
# mission
# one
# university
# way
# nasa
# etc
# solar
# name
# well
#
# Concept 49:
# long
# better
# since
# using
# digex pat writes
# data
# launch
# really
# know
# use
#
# Concept 50:
# lunar
# may
# earth
# time
# distribution
# think
# two
# days
# ve
# software
#
# Concept 51:
# nasa
# use
# mass
# much
# year
# aantal voordrachten
# news
# science
# hst
# people
#
# Concept 52:
# long
# distribution
# man
# look
# really
# solar
# jpl
# mass
# way
# nsmca
#
# Concept 53:
# much
# sky
# used
# days
# part
# even
# would
# look
# given
# aurora alaska
#
# Concept 54:
# nasa
# could
# posting
# toronto
# baalke
# us
# fred
# pat
# well
# get
#
# Concept 55:
# get
# way
# solar
# two
# cost
# moon
# people
# one
# last
# still
#
# Concept 56:
# would
# toronto
# program
# much
# solar
# also
# ca
# still
# space
# world
#
# Concept 57:
# space
# good
# eng
# prb
# prb access
# well
# life
# lunar
# nsmca
# point
#
# Concept 58:
# like
# one
# ca
# think
# time
# zoo
# zoo toronto
# years
# year
# could
#
# Concept 59:
# shuttle
# nasa
# posting
# launch
# need
# cost
# first
# long
# without
# spencer
#
# Concept 60:
# host
# first
# pat
# nasa
# may
# lunar
# like
# flight
# toronto
# mission
#
# Concept 61:
# make
# mission
# host
# would
# one
# may
# see
# satellite
# billion
# access digex
#
# Concept 62:
# mission
# know
# new
# station
# anyone
# real
# umd
# current
# still
# first
#
# Concept 63:
# shuttle
# space
# moon
# earth
# host
# like
# years
# one
# posting host
# idea
#
# Concept 64:
# earth
# pat
# toronto
# might
# good
# around
# back
# think
# news
# space
#
# Concept 65:
# nasa
# high
# orbit
# re
# time
# aangegeven men lid
# know
# host
# news
# uiuc
#
# Concept 66:
# might
# pat
# news
# posting
# use
# orbit
# one
# spacecraft
# well
# re
#
# Concept 67:
# get
# research
# re
# world
# big
# make
# isn
# moon
# nsmca
# solar
#
# Concept 68:
# also
# people
# posting host
# mission
# one
# us
# pat
# lot
# first
# anyone
#
# Concept 69:
# also
# think
# one
# system
# access digex
# digex
# idea
# cost
# missions
# large
#
# Concept 70:
# cost
# would
# idea
# work
# orbit
# really
# time
# long
# two
# project
#
# Concept 71:
# world
# system
# enough
# shuttle
# host
# space
# work
# aurora alaska
# writes article
# sun
#
# Concept 72:
# pat
# space
# new
# moon
# something
# lunar
# time
# ca
# hst
# many
#
# Concept 73:
# know
# toronto
# posting host
# may
# host
# aacs attitude
# isn
# much
# idea
# actually
#
# Concept 74:
# know
# get
# posting host
# earth
# zoo
# zoo toronto
# cost
# since
# idea
# might
#
# Concept 75:
# could
# earth
# people
# like
# solar
# space
# alaska
# cost
# access digex
# digex
#
# Concept 76:
# system
# orbit
# writes article
# would
# need
# since
# host
# first
# high
# large
#
# Concept 77:
# posting
# aangegeven men lid
# new
# know
# also
# use
# think
# like
# us
# get
#
# Concept 78:
# high
# much
# aantal voordrachten
# get
# first
# research
# thing
# world
# really
# distribution
#
# Concept 79:
# high
# shuttle
# people
# article
# also
# sky
# day
# pat
# like
# find
#
# Concept 80:
# like
# system
# hst
# years
# one
# space
# may
# see
# work
# solar
#
# Concept 81:
# writes
# aacs attitude
# one
# earth
# host
# article
# go
# know
# think
# even
#
# Concept 82:
# get
# since
# orbit
# may
# toronto
# see
# back
# would
# science
# cost
#
# Concept 83:
# earth
# work
# first
# shuttle
# things
# well
# see
# many
# anyone
# enough
#
# Concept 84:
# would
# could
# science
# access
# want
# time
# article
# also
# posting host
# us
#
# Concept 85:
# posting
# us
# go
# two
# posting host
# nasa
# think
# see
# much
# aangegeven men lid
#
# Concept 86:
# like
# also
# would
# posting host
# long
# go
# one
# use
# world
# right
#
# Concept 87:
# like
# orbit
# space
# get
# time
# earth
# may
# aantal voordrachten
# also
# us
#
# Concept 88:
# first
# aacs attitude
# could
# see
# like
# us
# access
# earth
# solar
# nsmca
#
# Concept 89:
# space
# would
# know
# one
# see
# host
# aacs attitude
# launch
# much
# work
#
# Concept 90:
# host
# think
# make
# orbit
# around
# lunar
# aacs attitude
# posting host
# work
# long
#
# Concept 91:
# like
# access
# work
# launch
# much
# program
# nasa
# aangegeven men lid
# maybe
# make
#
# Concept 92:
# would
# posting
# much
# space
# one
# alaska
# go
# us
# even
# big
#
# Concept 93:
# access
# know
# world
# aangegeven men
# would
# part
# earth
# large
# research
# posting
#
# Concept 94:
# would
# like
# nasa
# article
# jpl
# re
# new
# think
# make
# know
#
# Concept 95:
# aacs attitude
# aangegeven men lid
# would
# access digex
# digex
# world
# get
# posting host
# spencer
# something
#
# Concept 96:
# article
# aangegeven men lid
# posting host
# aams closed
# writes
# aantal voordrachten
# orbit
# aams closed bays
# could
# pat
#
# Concept 97:
# article
# writes
# get
# aacs attitude
# posting
# space
# satellite
# like
# news
# also
#
# Concept 98:
# aangegeven men lid
# writes
# host
# people
# would
# also
# aantal
# aams closed
# aams closed bays
# moon
#
# Concept 99:
# writes
# aangegeven
# aantal voordrachten met
# posting host
# world
# like
# aams closed
# launch
# part
# alaska

# %%
features
# Out:
# [u'space',
#  u'would',
#  u'nasa',
#  u'writes',
#  u'like',
#  u'article',
#  u'one',
#  u'shuttle',
#  u'alaska',
#  u'orbit',
#  u'elements',
#  u'afit',
#  u'afit af',
#  u'updated daily',
#  u'af',
#  u'celestial bbs',
#  u'software also available',
#  u'software also',
#  u'daily',
#  u'current',
#  u'jpl',
#  u'baalke',
#  u'kelvin jpl',
#  u'kelvin jpl nasa',
#  u'jpl nasa',
#  u'kelvin',
#  u'command',
#  u'nasa',
#  u'comet',
#  u'spacecraft',
#  u'alaska',
#  u'gene',
#  u'nasa',
#  u'raider',
#  u'acad',
#  u'acad alaska',
#  u'theporch',
#  u'theporch raider',
#  u'jpl nasa',
#  u'jpl',
#  u'space',
#  u'nasa',
#  u'earth',
#  u'launch',
#  u'research',
#  u'satellite',
#  u'part',
#  u'center',
#  u'venus',
#  u'software',
#  u'space',
#  u'shuttle',
#  u'mission',
#  u'hst',
#  u'information',
#  u'boost',
#  u'going',
#  u'station',
#  u'years',
#  u'data',
#  u'see',
#  u'might',
#  u'station',
#  u'fuel',
#  u'end',
#  u'sky',
#  u'different',
#  u'us',
#  u'power',
#  u'uiuc',
#  u'nasa',
#  u'station',
#  u'dc',
#  u'april',
#  u'going',
#  u'posting',
#  u'umd',
#  u'space',
#  u'high',
#  u'software',
#  u'alaska',
#  u'high',
#  u'system',
#  u'zoo',
#  u'zoo toronto',
#  u'mars',
#  u'spencer',
#  u'earth',
#  u'like',
#  u'toronto',
#  u'overhead',
#  u'allen',
#  u'reston',
#  u'isn',
#  u'time',
#  u'back',
#  u'atmosphere',
#  u'wrap',
#  u'much',
#  u'host',
#  u'space',
#  u'us',
#  u'access digex',
#  u'digex',
#  u'power',
#  u'many',
#  u'anyone',
#  u'shuttle',
#  u'station',
#  u'sky',
#  u'nasa',
#  u'overhead',
#  u'alaska',
#  u'university',
#  u'program',
#  u'systems',
#  u'distribution',
#  u'writes',
#  u'dennis',
#  u'project',
#  u'shuttle',
#  u'launch',
#  u'mission',
#  u'ti',
#  u'toronto',
#  u'writes article',
#  u'option',
#  u'nasa',
#  u'boost',
#  u'planet',
#  u'real',
#  u'spacecraft',
#  u'give',
#  u'first',
#  u'idea',
#  u'use',
#  u'news',
#  u'atmosphere',
#  u'radio',
#  u'done',
#  u'launch',
#  u'something',
#  u'need',
#  u'new',
#  u'first',
#  u'april',
#  u'moon',
#  u'put',
#  u'big',
#  u'might',
#  u'launch',
#  u'would',
#  u'could',
#  u'go',
#  u'way',
#  u'going',
#  u'think',
#  u'station',
#  u'find',
#  u'au',
#  u'toronto',
#  u'data',
#  u'program',
#  u'propulsion',
#  u'space',
#  u'way',
#  u'cost',
#  u'jpl',
#  u'orbital',
#  u'long',
#  u'would',
#  u'may',
#  u'launch',
#  u'moon',
#  u'orbit',
#  u'flight',
#  u'good',
#  u'way',
#  u'know',
#  u'program',
#  u'alaska',
#  u'launch',
#  u'us',
#  u'posting host',
#  u'earth',
#  u'posting',
#  u'host',
#  u'april',
#  u'one',
#  u'going',
#  u'software',
#  u'see',
#  u'years',
#  u'commercial',
#  u'toronto',
#  u'world',
#  u'going',
#  u'first',
#  u'us',
#  u'year',
#  u'launch',
#  u'system',
#  u'pluto',
#  u'shuttle',
#  u'well',
#  u'distribution',
#  u'satellite',
#  u'around',
#  u'talking',
#  u'us',
#  u'space',
#  u'using',
#  u'sun',
#  u'alaska',
#  u'solar',
#  u'toronto',
#  u'moon',
#  u'ca',
#  u'mars',
#  u'nasa',
#  u'flight',
#  u'long',
#  u'point',
#  u'well',
#  u'mass',
#  u'also',
#  u'posting host',
#  u'moon',
#  u'ether',
#  u'every',
#  u'get',
#  u'make',
#  u'could',
#  u'technology',
#  u'venus',
#  u'software',
#  u'jpl',
#  u'mission',
#  u'try',
#  u'go',
#  u'alaska',
#  u'sky',
#  u'flight',
#  u'data',
#  u'could',
#  u'make',
#  u'also',
#  u're',
#  u'first',
#  u'actually',
#  u'launch',
#  u'lunar',
#  u'need',
#  u'money',
#  u'posting',
#  u'go',
#  u'find',
#  u'commercial',
#  u'observatory',
#  u'sky',
#  u'nasa',
#  u'orbit',
#  u'solar',
#  u'data',
#  u'shuttle',
#  u'ftp',
#  u'market',
#  u'satellite',
#  u'also',
#  u'sun',
#  u'pat',
#  u'see',
#  u'satellites',
#  u'able',
#  u'commercial',
#  u'pluto',
#  u'writes',
#  u'long',
#  u'spencer',
#  u'jpl',
#  u'ca',
#  u'telescope',
#  u'system',
#  u'since',
#  u'hst',
#  u'solar',
#  u'station',
#  u'say',
#  u'article',
#  u'space',
#  u'data',
#  u'research',
#  u'project',
#  u'light',
#  u'least',
#  u'part',
#  u'things',
#  u'toronto',
#  u'au',
#  u'even',
#  u'one',
#  u'would',
#  u'moon',
#  u'us',
#  u'science',
#  u'orbit',
#  u'without',
#  u'part',
#  u'earth',
#  u'flight',
#  u'space',
#  u'two',
#  u'pat',
#  u'back',
#  u'different',
#  u'high',
#  u'like',
#  u'probe',
#  u'part',
#  u're',
#  u'see',
#  u'moon',
#  u'hst',
#  u'software',
#  u'vax',
#  u'long',
#  u'shuttle',
#  u'even',
#  u'might',
#  u'sky',
#  u'moon',
#  u'time',
#  u'us',
#  u'see',
#  u'look',
#  u'done',
#  u'space',
#  u'would',
#  u'problem',
#  u'well',
#  u'us',
#  u'mission',
#  u'access',
#  u'ti',
#  u'pat',
#  u'need',
#  u'right',
#  u'problem',
#  u'hst',
#  u'might',
#  u'would',
#  u'year',
#  u'people',
#  u'around',
#  u'moon',
#  u'mars',
#  u'think',
#  u'help',
#  u'probes',
#  u'system',
#  u'earth',
#  u'large',
#  u'program',
#  u'think',
#  u'also',
#  u'want',
#  u'hst',
#  u'two',
#  u'alaska',
#  u'toronto',
#  u'moon',
#  u're',
#  u'sky',
#  u'program',
#  u'two',
#  u'right',
#  u'new',
#  u'something',
#  u'use',
#  u'planet',
#  u'earth',
#  u'year',
#  u'work',
#  u'space',
#  u'make',
#  u'shuttle',
#  u'even',
#  u'spencer',
#  u'solar system',
#  u'real',
#  u'see',
#  u'also',
#  u'spacecraft',
#  u'billion',
#  u'dc',
#  u'flight',
#  u'shuttle',
#  u'one',
#  u'get',
#  u'moon',
#  u'moon',
#  u'need',
#  u'access',
#  u'put',
#  u'work',
#  u'would',
#  u'orbit',
#  u'world',
#  u'data',
#  u'software',
#  u'one',
#  u'world',
#  u'sky',
#  u'sun',
#  u'new',
#  u'data',
#  u'things',
#  u'alaska',
#  u'distribution',
#  u're',
#  u'use',
#  u'system',
#  u'nasa',
#  u'well',
#  u'world',
#  u'launch',
#  u'solar',
#  u'government',
#  u'good',
#  u'lunar',
#  u'solar',
#  u'research',
#  u'far',
#  u'way',
#  u'host',
#  u'sky',
#  u'first',
#  u'shuttle',
#  u'zoo',
#  u'zoo toronto',
#  u'distribution',
#  u'something',
#  u'man',
#  u'government',
#  u'even',
#  u'want',
#  u'costs',
#  u'made',
#  u'posting host',
#  u'news',
#  u'pat',
#  u'us',
#  u'alaska',
#  u'one',
#  u'go',
#  u'research',
#  u'since',
#  u'point',
#  u'part',
#  u'design',
#  u'power',
#  u'idea',
#  u'well',
#  u'would',
#  u'mission',
#  u'say',
#  u'used',
#  u'better',
#  u'make',
#  u'money',
#  u'shuttle',
#  u'make',
#  u'could',
#  u'anyone',
#  u'see',
#  u'think',
#  u'alaska',
#  u'much',
#  u'news',
#  u'way',
#  u'new',
#  u'mission',
#  u'one',
#  u'university',
#  u'way',
#  u'nasa',
#  u'etc',
#  u'solar',
#  u'name',
#  u'well',
#  u'long',
#  u'better',
#  u'since',
#  u'using',
#  u'digex pat writes',
#  u'data',
#  u'launch',
#  u'really',
#  u'know',
#  u'use',
#  u'lunar',
#  u'may',
#  u'earth',
#  u'time',
#  u'distribution',
#  u'think',
#  u'two',
#  u'days',
#  u've',
#  u'software',
#  u'nasa',
#  u'use',
#  u'mass',
#  u'much',
#  u'year',
#  u'aantal voordrachten',
#  u'news',
#  u'science',
#  u'hst',
#  u'people',
#  u'long',
#  u'distribution',
#  u'man',
#  u'look',
#  u'really',
#  u'solar',
#  u'jpl',
#  u'mass',
#  u'way',
#  u'nsmca',
#  u'much',
#  u'sky',
#  u'used',
#  u'days',
#  u'part',
#  u'even',
#  u'would',
#  u'look',
#  u'given',
#  u'aurora alaska',
#  u'nasa',
#  u'could',
#  u'posting',
#  u'toronto',
#  u'baalke',
#  u'us',
#  u'fred',
#  u'pat',
#  u'well',
#  u'get',
#  u'get',
#  u'way',
#  u'solar',
#  u'two',
#  u'cost',
#  u'moon',
#  u'people',
#  u'one',
#  u'last',
#  u'still',
#  u'would',
#  u'toronto',
#  u'program',
#  u'much',
#  u'solar',
#  u'also',
#  u'ca',
#  u'still',
#  u'space',
#  u'world',
#  u'space',
#  u'good',
#  u'eng',
#  u'prb',
#  u'prb access',
#  u'well',
#  u'life',
#  u'lunar',
#  u'nsmca',
#  u'point',
#  u'like',
#  u'one',
#  u'ca',
#  u'think',
#  u'time',
#  u'zoo',
#  u'zoo toronto',
#  u'years',
#  u'year',
#  u'could',
#  u'shuttle',
#  u'nasa',
#  u'posting',
#  u'launch',
#  u'need',
#  u'cost',
#  u'first',
#  u'long',
#  u'without',
#  u'spencer',
#  u'host',
#  u'first',
#  u'pat',
#  u'nasa',
#  u'may',
#  u'lunar',
#  u'like',
#  u'flight',
#  u'toronto',
#  u'mission',
#  u'make',
#  u'mission',
#  u'host',
#  u'would',
#  u'one',
#  u'may',
#  u'see',
#  u'satellite',
#  u'billion',
#  u'access digex',
#  u'mission',
#  u'know',
#  u'new',
#  u'station',
#  u'anyone',
#  u'real',
#  u'umd',
#  u'current',
#  u'still',
#  u'first',
#  u'shuttle',
#  u'space',
#  u'moon',
#  u'earth',
#  u'host',
#  u'like',
#  u'years',
#  u'one',
#  u'posting host',
#  u'idea',
#  u'earth',
#  u'pat',
#  u'toronto',
#  u'might',
#  u'good',
#  u'around',
#  u'back',
#  u'think',
#  u'news',
#  u'space',
#  u'nasa',
#  u'high',
#  u'orbit',
#  u're',
#  u'time',
#  u'aangegeven men lid',
#  u'know',
#  u'host',
#  u'news',
#  u'uiuc',
#  u'might',
#  u'pat',
#  u'news',
#  u'posting',
#  u'use',
#  u'orbit',
#  u'one',
#  u'spacecraft',
#  u'well',
#  u're',
#  u'get',
#  u'research',
#  u're',
#  u'world',
#  u'big',
#  u'make',
#  u'isn',
#  u'moon',
#  u'nsmca',
#  u'solar',
#  u'also',
#  u'people',
#  u'posting host',
#  u'mission',
#  u'one',
#  u'us',
#  u'pat',
#  u'lot',
#  u'first',
#  u'anyone',
#  u'also',
#  u'think',
#  u'one',
#  u'system',
#  u'access digex',
#  u'digex',
#  u'idea',
#  u'cost',
#  u'missions',
#  u'large',
#  u'cost',
#  u'would',
#  u'idea',
#  u'work',
#  u'orbit',
#  u'really',
#  u'time',
#  u'long',
#  u'two',
#  u'project',
#  u'world',
#  u'system',
#  u'enough',
#  u'shuttle',
#  u'host',
#  u'space',
#  u'work',
#  u'aurora alaska',
#  u'writes article',
#  u'sun',
#  u'pat',
#  u'space',
#  u'new',
#  u'moon',
#  u'something',
#  u'lunar',
#  u'time',
#  u'ca',
#  u'hst',
#  u'many',
#  u'know',
#  u'toronto',
#  u'posting host',
#  u'may',
#  u'host',
#  u'aacs attitude',
#  u'isn',
#  u'much',
#  u'idea',
#  u'actually',
#  u'know',
#  u'get',
#  u'posting host',
#  u'earth',
#  u'zoo',
#  u'zoo toronto',
#  u'cost',
#  u'since',
#  u'idea',
#  u'might',
#  u'could',
#  u'earth',
#  u'people',
#  u'like',
#  u'solar',
#  u'space',
#  u'alaska',
#  u'cost',
#  u'access digex',
#  u'digex',
#  u'system',
#  u'orbit',
#  u'writes article',
#  u'would',
#  u'need',
#  u'since',
#  u'host',
#  u'first',
#  u'high',
#  u'large',
#  u'posting',
#  u'aangegeven men lid',
#  u'new',
#  u'know',
#  u'also',
#  u'use',
#  u'think',
#  u'like',
#  u'us',
#  u'get',
#  u'high',
#  u'much',
#  u'aantal voordrachten',
#  u'get',
#  u'first',
#  u'research',
#  u'thing',
#  u'world',
#  u'really',
#  u'distribution',
#  u'high',
#  u'shuttle',
#  u'people',
#  u'article',
#  u'also',
#  u'sky',
#  u'day',
#  u'pat',
#  u'like',
#  u'find',
#  u'like',
#  u'system',
#  u'hst',
#  u'years',
#  u'one',
#  u'space',
#  u'may',
#  u'see',
#  u'work',
#  u'solar',
#  u'writes',
#  u'aacs attitude',
#  u'one',
#  u'earth',
#  u'host',
#  u'article',
#  u'go',
#  u'know',
#  u'think',
#  u'even',
#  u'get',
#  u'since',
#  u'orbit',
#  u'may',
#  u'toronto',
#  u'see',
#  u'back',
#  u'would',
#  u'science',
#  u'cost',
#  u'earth',
#  u'work',
#  u'first',
#  u'shuttle',
#  u'things',
#  u'well',
#  u'see',
#  u'many',
#  u'anyone',
#  u'enough',
#  u'would',
#  u'could',
#  u'science',
#  u'access',
#  u'want',
#  u'time',
#  u'article',
#  u'also',
#  u'posting host',
#  u'us',
#  u'posting',
#  u'us',
#  u'go',
#  u'two',
#  u'posting host',
#  u'nasa',
#  u'think',
#  u'see',
#  u'much',
#  u'aangegeven men lid',
#  u'like',
#  u'also',
#  u'would',
#  u'posting host',
#  u'long',
#  u'go',
#  u'one',
#  u'use',
#  u'world',
#  u'right',
#  u'like',
#  u'orbit',
#  u'space',
#  u'get',
#  u'time',
#  u'earth',
#  u'may',
#  u'aantal voordrachten',
#  u'also',
#  u'us',
#  u'first',
#  u'aacs attitude',
#  u'could',
#  u'see',
#  u'like',
#  u'us',
#  u'access',
#  u'earth',
#  u'solar',
#  u'nsmca',
#  u'space',
#  u'would',
#  u'know',
#  u'one',
#  u'see',
#  u'host',
#  u'aacs attitude',
#  u'launch',
#  u'much',
#  u'work',
#  u'host',
#  u'think',
#  u'make',
#  u'orbit',
#  u'around',
#  u'lunar',
#  u'aacs attitude',
#  u'posting host',
#  u'work',
#  u'long',
#  u'like',
#  u'access',
#  u'work',
#  u'launch',
#  u'much',
#  u'program',
#  u'nasa',
#  u'aangegeven men lid',
#  u'maybe',
#  u'make',
#  u'would',
#  u'posting',
#  u'much',
#  u'space',
#  u'one',
#  u'alaska',
#  u'go',
#  u'us',
#  u'even',
#  u'big',
#  u'access',
#  u'know',
#  u'world',
#  u'aangegeven men',
#  u'would',
#  u'part',
#  u'earth',
#  u'large',
#  u'research',
#  u'posting',
#  u'would',
#  u'like',
#  u'nasa',
#  u'article',
#  u'jpl',
#  u're',
#  u'new',
#  u'think',
#  u'make',
#  u'know',
#  u'aacs attitude',
#  u'aangegeven men lid',
#  u'would',
#  u'access digex',
#  u'digex',
#  u'world',
#  u'get',
#  u'posting host',
#  u'spencer',
#  u'something',
#  u'article',
#  u'aangegeven men lid',
#  u'posting host',
#  u'aams closed',
#  u'writes',
#  u'aantal voordrachten',
#  u'orbit',
#  u'aams closed bays',
#  u'could',
#  u'pat',
#  u'article',
#  u'writes',
#  u'get',
#  u'aacs attitude',
#  u'posting',
#  u'space',
#  u'satellite',
#  u'like',
#  u'news',
#  u'also',
#  u'aangegeven men lid',
#  u'writes',
#  u'host',
#  u'people',
#  u'would',
#  u'also',
#  u'aantal',
#  u'aams closed',
#  u'aams closed bays',
#  u'moon',
#  u'writes',
#  u'aangegeven',
#  u'aantal voordrachten met',
#  u'posting host',
#  u'world',
#  u'like',
#  u'aams closed',
#  u'launch',
#  u'part',
#  u'alaska']

# %% [markdown]
# <p style="color:blue">
# Convert into set to get unique features
# </p>

# %%
uniquefeatures = set(features)

# %%
uniquefeatures
# Out:
# {u'aacs attitude',
#  u'aams closed',
#  u'aams closed bays',
#  u'aangegeven',
#  u'aangegeven men',
#  u'aangegeven men lid',
#  u'aantal',
#  u'aantal voordrachten',
#  u'aantal voordrachten met',
#  u'able',
#  u'acad',
#  u'acad alaska',
#  u'access',
#  u'access digex',
#  u'actually',
#  u'af',
#  u'afit',
#  u'afit af',
#  u'alaska',
#  u'allen',
#  u'also',
#  u'anyone',
#  u'april',
#  u'around',
#  u'article',
#  u'atmosphere',
#  u'au',
#  u'aurora alaska',
#  u'baalke',
#  u'back',
#  u'better',
#  u'big',
#  u'billion',
#  u'boost',
#  u'ca',
#  u'celestial bbs',
#  u'center',
#  u'comet',
#  u'command',
#  u'commercial',
#  u'cost',
#  u'costs',
#  u'could',
#  u'current',
#  u'daily',
#  u'data',
#  u'day',
#  u'days',
#  u'dc',
#  u'dennis',
#  u'design',
#  u'different',
#  u'digex',
#  u'digex pat writes',
#  u'distribution',
#  u'done',
#  u'earth',
#  u'elements',
#  u'end',
#  u'eng',
#  u'enough',
#  u'etc',
#  u'ether',
#  u'even',
#  u'every',
#  u'far',
#  u'find',
#  u'first',
#  u'flight',
#  u'fred',
#  u'ftp',
#  u'fuel',
#  u'gene',
#  u'get',
#  u'give',
#  u'given',
#  u'go',
#  u'going',
#  u'good',
#  u'government',
#  u'help',
#  u'high',
#  u'host',
#  u'hst',
#  u'idea',
#  u'information',
#  u'isn',
#  u'jpl',
#  u'jpl nasa',
#  u'kelvin',
#  u'kelvin jpl',
#  u'kelvin jpl nasa',
#  u'know',
#  u'large',
#  u'last',
#  u'launch',
#  u'least',
#  u'life',
#  u'light',
#  u'like',
#  u'long',
#  u'look',
#  u'lot',
#  u'lunar',
#  u'made',
#  u'make',
#  u'man',
#  u'many',
#  u'market',
#  u'mars',
#  u'mass',
#  u'may',
#  u'maybe',
#  u'might',
#  u'mission',
#  u'missions',
#  u'money',
#  u'moon',
#  u'much',
#  u'name',
#  u'nasa',
#  u'need',
#  u'new',
#  u'news',
#  u'nsmca',
#  u'observatory',
#  u'one',
#  u'option',
#  u'orbit',
#  u'orbital',
#  u'overhead',
#  u'part',
#  u'pat',
#  u'people',
#  u'planet',
#  u'pluto',
#  u'point',
#  u'posting',
#  u'posting host',
#  u'power',
#  u'prb',
#  u'prb access',
#  u'probe',
#  u'probes',
#  u'problem',
#  u'program',
#  u'project',
#  u'propulsion',
#  u'put',
#  u'radio',
#  u'raider',
#  u're',
#  u'real',
#  u'really',
#  u'research',
#  u'reston',
#  u'right',
#  u'satellite',
#  u'satellites',
#  u'say',
#  u'science',
#  u'see',
#  u'shuttle',
#  u'since',
#  u'sky',
#  u'software',
#  u'software also',
#  u'software also available',
#  u'solar',
#  u'solar system',
#  u'something',
#  u'space',
#  u'spacecraft',
#  u'spencer',
#  u'station',
#  u'still',
#  u'sun',
#  u'system',
#  u'systems',
#  u'talking',
#  u'technology',
#  u'telescope',
#  u'theporch',
#  u'theporch raider',
#  u'thing',
#  u'things',
#  u'think',
#  u'ti',
#  u'time',
#  u'toronto',
#  u'try',
#  u'two',
#  u'uiuc',
#  u'umd',
#  u'university',
#  u'updated daily',
#  u'us',
#  u'use',
#  u'used',
#  u'using',
#  u'vax',
#  u've',
#  u'venus',
#  u'want',
#  u'way',
#  u'well',
#  u'without',
#  u'work',
#  u'world',
#  u'would',
#  u'wrap',
#  u'writes',
#  u'writes article',
#  u'year',
#  u'years',
#  u'zoo',
#  u'zoo toronto'}

# %%
wordDictFeatures = dict.fromkeys(uniquefeatures, 0)

# %%
for word in features:
    wordDictFeatures[word]+=1

# %% [markdown]
# <p style="color:blue">
# Additional analysis using Dictionary
# </p>

# %%
wordDictFeatures
# Out:
# {u'aacs attitude': 7,
#  u'aams closed': 3,
#  u'aams closed bays': 2,
#  u'aangegeven': 1,
#  u'aangegeven men': 1,
#  u'aangegeven men lid': 7,
#  u'aantal': 1,
#  u'aantal voordrachten': 4,
#  u'aantal voordrachten met': 1,
#  u'able': 1,
#  u'acad': 1,
#  u'acad alaska': 1,
#  u'access': 6,
#  u'access digex': 5,
#  u'actually': 2,
#  u'af': 1,
#  u'afit': 1,
#  u'afit af': 1,
#  u'alaska': 14,
#  u'allen': 1,
#  u'also': 15,
#  u'anyone': 5,
#  u'april': 3,
#  u'around': 4,
#  u'article': 8,
#  u'atmosphere': 2,
#  u'au': 2,
#  u'aurora alaska': 2,
#  u'baalke': 2,
#  u'back': 4,
#  u'better': 2,
#  u'big': 3,
#  u'billion': 2,
#  u'boost': 2,
#  u'ca': 5,
#  u'celestial bbs': 1,
#  u'center': 1,
#  u'comet': 1,
#  u'command': 1,
#  u'commercial': 3,
#  u'cost': 8,
#  u'costs': 1,
#  u'could': 10,
#  u'current': 2,
#  u'daily': 1,
#  u'data': 8,
#  u'day': 1,
#  u'days': 2,
#  u'dc': 2,
#  u'dennis': 1,
#  u'design': 1,
#  u'different': 2,
#  u'digex': 4,
#  u'digex pat writes': 1,
#  u'distribution': 7,
#  u'done': 2,
#  u'earth': 16,
#  u'elements': 1,
#  u'end': 1,
#  u'eng': 1,
#  u'enough': 2,
#  u'etc': 1,
#  u'ether': 1,
#  u'even': 7,
#  u'every': 1,
#  u'far': 1,
#  u'find': 3,
#  u'first': 13,
#  u'flight': 6,
#  u'fred': 1,
#  u'ftp': 1,
#  u'fuel': 1,
#  u'gene': 1,
#  u'get': 12,
#  u'give': 1,
#  u'given': 1,
#  u'go': 8,
#  u'going': 5,
#  u'good': 4,
#  u'government': 2,
#  u'help': 1,
#  u'high': 7,
#  u'host': 14,
#  u'hst': 8,
#  u'idea': 7,
#  u'information': 1,
#  u'isn': 3,
#  u'jpl': 7,
#  u'jpl nasa': 2,
#  u'kelvin': 1,
#  u'kelvin jpl': 1,
#  u'kelvin jpl nasa': 1,
#  u'know': 11,
#  u'large': 4,
#  u'last': 1,
#  u'launch': 14,
#  u'least': 1,
#  u'life': 1,
#  u'light': 1,
#  u'like': 17,
#  u'long': 10,
#  u'look': 3,
#  u'lot': 1,
#  u'lunar': 7,
#  u'made': 1,
#  u'make': 10,
#  u'man': 2,
#  u'many': 3,
#  u'market': 1,
#  u'mars': 3,
#  u'mass': 3,
#  u'may': 8,
#  u'maybe': 1,
#  u'might': 7,
#  u'mission': 10,
#  u'missions': 1,
#  u'money': 2,
#  u'moon': 16,
#  u'much': 11,
#  u'name': 1,
#  u'nasa': 19,
#  u'need': 6,
#  u'new': 8,
#  u'news': 8,
#  u'nsmca': 4,
#  u'observatory': 1,
#  u'one': 19,
#  u'option': 1,
#  u'orbit': 13,
#  u'orbital': 1,
#  u'overhead': 2,
#  u'part': 8,
#  u'pat': 12,
#  u'people': 7,
#  u'planet': 2,
#  u'pluto': 2,
#  u'point': 3,
#  u'posting': 11,
#  u'posting host': 14,
#  u'power': 3,
#  u'prb': 1,
#  u'prb access': 1,
#  u'probe': 1,
#  u'probes': 1,
#  u'problem': 2,
#  u'program': 7,
#  u'project': 3,
#  u'propulsion': 1,
#  u'put': 2,
#  u'radio': 1,
#  u'raider': 1,
#  u're': 8,
#  u'real': 3,
#  u'really': 4,
#  u'research': 7,
#  u'reston': 1,
#  u'right': 3,
#  u'satellite': 5,
#  u'satellites': 1,
#  u'say': 2,
#  u'science': 4,
#  u'see': 14,
#  u'shuttle': 16,
#  u'since': 6,
#  u'sky': 10,
#  u'software': 7,
#  u'software also': 1,
#  u'software also available': 1,
#  u'solar': 13,
#  u'solar system': 1,
#  u'something': 5,
#  u'space': 23,
#  u'spacecraft': 4,
#  u'spencer': 5,
#  u'station': 7,
#  u'still': 3,
#  u'sun': 4,
#  u'system': 9,
#  u'systems': 1,
#  u'talking': 1,
#  u'technology': 1,
#  u'telescope': 1,
#  u'theporch': 1,
#  u'theporch raider': 1,
#  u'thing': 1,
#  u'things': 3,
#  u'think': 13,
#  u'ti': 2,
#  u'time': 9,
#  u'toronto': 13,
#  u'try': 1,
#  u'two': 7,
#  u'uiuc': 2,
#  u'umd': 2,
#  u'university': 2,
#  u'updated daily': 1,
#  u'us': 17,
#  u'use': 8,
#  u'used': 2,
#  u'using': 2,
#  u'vax': 1,
#  u've': 1,
#  u'venus': 2,
#  u'want': 3,
#  u'way': 8,
#  u'well': 10,
#  u'without': 2,
#  u'work': 9,
#  u'world': 12,
#  u'would': 22,
#  u'wrap': 1,
#  u'writes': 8,
#  u'writes article': 3,
#  u'year': 5,
#  u'years': 5,
#  u'zoo': 4,
#  u'zoo toronto': 4}

# %% [markdown]
# <h4>Observation</h4>
# <p style="color:brown">
# Some really interesting words/phrases show up and they are all related to space and astronomy including shuttle, satellite, spacecraft, venus, jpl, launch, mission, moon, etc.
# </p>

# %% [markdown]
# <h4>Inference</h4>
# <p style="color:blue">
# Using LSA we have been able to identify that the conversation is primarily about space and astronomy.
# we have derived features from unstructured data
# </p>
